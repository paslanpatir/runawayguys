# %%
import sys
import os

# go up one level and add src/ to the path
sys.path.append(os.path.abspath(os.path.join("..", "src")))

from Messages import Message
from DatabaseHandler import DatabaseHandler

# %%
language = 'EN'
msg = Message(language)
